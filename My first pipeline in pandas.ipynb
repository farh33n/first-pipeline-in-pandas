# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Pandas allows chaining together functions that expect Series, DataFrames or GroupBy objects

# %% [markdown]
# #### create dataframe by reading the data set

# %%
df = pd.read_csv("titanic.csv", sep="\t", index_col='PassengerId')
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# #### starts the index from 0

# %%
def transform_index(df):
    df.index = np.arange(df.shape[0])
    return df

# %% [markdown]
# #### we noticed few NaNs in "Cabin" column

# %%
df["Cabin"].isna().sum()
# Out:
# 125

# %% [markdown]
# #### Actually we have lots of (=125) NaNs
# #### We would like to replace NaN by looking at the "Sex" column, It is replaced by the cabin which was frequent for a particular sex in that row

# %%
def replace_nans_cabin(df):
    most_common = df.groupby('Sex')['Cabin'].apply(lambda x: x.value_counts().index[0]).reset_index()
    df.loc[(df['Cabin'].isnull()) & (df.Sex == 'female'), 'Cabin'] = most_common[most_common['Sex']=='female']['Cabin'][0]
    df.loc[(df['Cabin'].isnull()) & (df.Sex == 'male'), 'Cabin'] = most_common[most_common['Sex']=='male']['Cabin'][1]
    return df

# %% [markdown]
# #### We also replace NaNs in "Age" column by replacing it with the mean age of that particular sex

# %%
def replace_nans_age(df):
    df['Age'] = df["Age"].fillna(df.groupby("Sex")["Age"].transform('mean'))
    return df

# %% [markdown]
# #### Creates pipeline

# %%
(df.pipe(transform_index)
.pipe(replace_nans_cabin)
 .pipe(replace_nans_age)
)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# 6           0       1                            McCarthy, Mr. Timothy J
# 7           0       3                     Palsson, Master. Gosta Leonard
# 8           1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9           1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 10          1       3                    Sandstrom, Miss. Marguerite Rut
# 11          1       1                           Bonnell, Miss. Elizabeth
# 12          0       3                     Saundercock, Mr. William Henry
# 13          0       3                        Andersson, Mr. Anders Johan
# 14          0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 15          1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 16          0       3                               Rice, Master. Eugene
# 17          1       2                       Williams, Mr. Charles Eugene
# 18          0       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 19          1       3                            Masselmani, Mrs. Fatima
# 20          0       2                               Fynney, Mr. Joseph J
# 21          1       2                              Beesley, Mr. Lawrence
# 22          1       3                        McGowan, Miss. Anna "Annie"
# 23          1       1                       Sloper, Mr. William Thompson
# 24          0       3                      Palsson, Miss. Torborg Danira
# 25          1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 26          0       3                            Emir, Mr. Farred Chehab
# 27          0       1                     Fortune, Mr. Charles Alexander
# 28          1       3                      O'Dwyer, Miss. Ellen "Nellie"
# 29          0       3                                Todoroff, Mr. Lalio
# ..        ...     ...                                                ...
# 126         0       3                                McMahon, Mr. Martin
# 127         1       3                          Madsen, Mr. Fridtjof Arne
# 128         1       3                                  Peter, Miss. Anna
# 129         0       3                                 Ekstrom, Mr. Johan
# 130         0       3                               Drazenoic, Mr. Jozef
# 131         0       3                     Coelho, Mr. Domingos Fernandeo
# 132         0       3     Robins, Mrs. Alexander A (Grace Charity Laury)
# 133         1       2      Weisz, Mrs. Leopold (Mathilde Francoise Pede)
# 134         0       2                     Sobey, Mr. Samuel James Hayden
# 135         0       2                                 Richard, Mr. Emile
# 136         1       1                       Newsom, Miss. Helen Monypeny
# 137         0       1                        Futrelle, Mr. Jacques Heath
# 138         0       3                                Osen, Mr. Olaf Elon
# 139         0       1                                 Giglio, Mr. Victor
# 140         0       3                      Boulos, Mrs. Joseph (Sultana)
# 141         1       3                           Nysten, Miss. Anna Sofia
# 142         1       3  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 143         0       3                                Burke, Mr. Jeremiah
# 144         0       2                         Andrew, Mr. Edgardo Samuel
# 145         0       2                       Nicholls, Mr. Joseph Charles
# 146         1       3       Andersson, Mr. August Edvard ("Wennerstrom")
# 147         0       3                   Ford, Miss. Robina Maggie "Ruby"
# 148         0       2           Navratil, Mr. Michel ("Louis M Hoffman")
# 149         0       2                  Byles, Rev. Thomas Roussel Davids
# 150         0       2                         Bateman, Rev. Robert James
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex        Age  SibSp  Parch              Ticket      Fare  \
# 0      male  22.000000      1      0           A/5 21171    7.2500
# 1    female  38.000000      1      0            PC 17599   71.2833
# 2    female  26.000000      0      0    STON/O2. 3101282    7.9250
# 3    female  35.000000      1      0              113803   53.1000
# 4      male  35.000000      0      0              373450    8.0500
# 5      male  30.326962      0      0              330877    8.4583
# 6      male  54.000000      0      0               17463   51.8625
# 7      male   2.000000      3      1              349909   21.0750
# 8    female  27.000000      0      2              347742   11.1333
# 9    female  14.000000      1      0              237736   30.0708
# 10   female   4.000000      1      1             PP 9549   16.7000
# 11   female  58.000000      0      0              113783   26.5500
# 12     male  20.000000      0      0           A/5. 2151    8.0500
# 13     male  39.000000      1      5              347082   31.2750
# 14   female  14.000000      0      0              350406    7.8542
# 15   female  55.000000      0      0              248706   16.0000
# 16     male   2.000000      4      1              382652   29.1250
# 17     male  30.326962      0      0              244373   13.0000
# 18   female  31.000000      1      0              345763   18.0000
# 19   female  24.468085      0      0                2649    7.2250
# 20     male  35.000000      0      0              239865   26.0000
# 21     male  34.000000      0      0              248698   13.0000
# 22   female  15.000000      0      0              330923    8.0292
# 23     male  28.000000      0      0              113788   35.5000
# 24   female   8.000000      3      1              349909   21.0750
# 25   female  38.000000      1      5              347077   31.3875
# 26     male  30.326962      0      0                2631    7.2250
# 27     male  19.000000      3      2               19950  263.0000
# 28   female  24.468085      0      0              330959    7.8792
# 29     male  30.326962      0      0              349216    7.8958
# ..      ...        ...    ...    ...                 ...       ...
# 126    male  30.326962      0      0              370372    7.7500
# 127    male  24.000000      0      0             C 17369    7.1417
# 128  female  24.468085      1      1                2668   22.3583
# 129    male  45.000000      0      0              347061    6.9750
# 130    male  33.000000      0      0              349241    7.8958
# 131    male  20.000000      0      0  SOTON/O.Q. 3101307    7.0500
# 132  female  47.000000      1      0           A/5. 3337   14.5000
# 133  female  29.000000      1      0              228414   26.0000
# 134    male  25.000000      0      0          C.A. 29178   13.0000
# 135    male  23.000000      0      0       SC/PARIS 2133   15.0458
# 136  female  19.000000      0      2               11752   26.2833
# 137    male  37.000000      1      0              113803   53.1000
# 138    male  16.000000      0      0                7534    9.2167
# 139    male  24.000000      0      0            PC 17593   79.2000
# 140  female  24.468085      0      2                2678   15.2458
# 141  female  22.000000      0      0              347081    7.7500
# 142  female  24.000000      1      0    STON/O2. 3101279   15.8500
# 143    male  19.000000      0      0              365222    6.7500
# 144    male  18.000000      0      0              231945   11.5000
# 145    male  19.000000      1      1          C.A. 33112   36.7500
# 146    male  27.000000      0      0              350043    7.7958
# 147  female   9.000000      2      2          W./C. 6608   34.3750
# 148    male  36.500000      0      2              230080   26.0000
# 149    male  42.000000      0      0              244310   13.0000
# 150    male  51.000000      0      0         S.O.P. 1166   12.5250
# 151  female  22.000000      1      0              113776   66.6000
# 152    male  55.500000      0      0          A.5. 11206    8.0500
# 153    male  40.500000      0      2            A/5. 851   14.5000
# 154    male  30.326962      0      0           Fa 265302    7.3125
# 155    male  51.000000      0      1            PC 17597   61.3792
#
#            Cabin Embarked
# 0            D26        S
# 1            C85        C
# 2          F E69        S
# 3           C123        S
# 4            D26        S
# 5            D26        Q
# 6            E46        S
# 7            D26        S
# 8          F E69        S
# 9          F E69        C
# 10            G6        S
# 11          C103        S
# 12           D26        S
# 13           D26        S
# 14         F E69        S
# 15         F E69        S
# 16           D26        Q
# 17           D26        S
# 18         F E69        S
# 19         F E69        C
# 20           D26        S
# 21           D56        S
# 22         F E69        Q
# 23            A6        S
# 24         F E69        S
# 25         F E69        S
# 26           D26        C
# 27   C23 C25 C27        S
# 28         F E69        Q
# 29           D26        S
# ..           ...      ...
# 126          D26        Q
# 127          D26        S
# 128        F E69        C
# 129          D26        S
# 130          D26        C
# 131          D26        S
# 132        F E69        S
# 133        F E69        S
# 134          D26        S
# 135          D26        C
# 136          D47        S
# 137         C123        S
# 138          D26        S
# 139          B86        C
# 140        F E69        C
# 141        F E69        S
# 142        F E69        S
# 143          D26        Q
# 144          D26        S
# 145          D26        S
# 146          D26        S
# 147        F E69        S
# 148           F2        S
# 149          D26        S
# 150          D26        S
# 151           C2        S
# 152          D26        S
# 153          D26        S
# 154          D26        S
# 155          D26        C
#
# [156 rows x 11 columns]
